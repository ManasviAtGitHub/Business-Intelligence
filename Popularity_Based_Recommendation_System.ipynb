# %% [markdown]
# <a href="https://colab.research.google.com/github/ManasviAtGitHub/Business-Intelligence/blob/main/Popularity_Based_Recommendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# These datasets are hosted on: https://archive.ics.uci.edu/ml/datasets/Restaurant+%26+consumer+data
#
# They were originally published by: Blanca Vargas-Govea, Juan Gabriel GonzÃ¡lez-Serna, Rafael Ponce-MedellÃ­n. Effects of relevant contextual features in the performance of a restaurant recommender system. In RecSysâ€™11: Workshop on Context Aware Recommender Systems (CARS-2011), Chicago, IL, USA, October 23, 2011.

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
cd drive/MyDrive/practice_datasets/
# Out:
# /content/drive/MyDrive/practice_datasets

# %%
frame = pd.read_csv('rating_final.csv')
cuisine = pd.read_csv('chefmozcuisine.csv')

# %%
frame.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
frame.describe()
# Out:
#              placeID       rating  food_rating  service_rating
# count    1161.000000  1161.000000  1161.000000     1161.000000
# mean   134192.041344     1.199828     1.215332        1.090439
# std      1100.916275     0.773282     0.792294        0.790844
# min    132560.000000     0.000000     0.000000        0.000000
# 25%    132856.000000     1.000000     1.000000        0.000000
# 50%    135030.000000     1.000000     1.000000        1.000000
# 75%    135059.000000     2.000000     2.000000        2.000000
# max    135109.000000     2.000000     2.000000        2.000000

# %%
cuisine.head()
# Out:
#    placeID        Rcuisine
# 0   135110         Spanish
# 1   135109         Italian
# 2   135107  Latin_American
# 3   135106         Mexican
# 4   135105       Fast_Food

# %%
cuisine['Rcuisine'].describe()
# Out:
# count         916
# unique         59
# top       Mexican
# freq          239
# Name: Rcuisine, dtype: object

# %% [markdown]
# Most rated places

# %%
rating_count = pd.DataFrame(frame.groupby('placeID')['rating'].count())
rating_count.sort_values('rating', ascending=False).head()
# Out:
#          rating
# placeID
# 135085       36
# 132825       32
# 135032       28
# 135052       25
# 132834       25

# %%
rating_count.sort_values('rating', ascending = False).head(10)
# Out:
#          rating
# placeID
# 135085       36
# 132825       32
# 135032       28
# 135052       25
# 132834       25
# 135038       24
# 135060       22
# 135062       21
# 135042       20
# 132862       18

# %%
most_rated_places = pd.DataFrame([135085, 132825, 135032, 135052, 132834], columns=['placeID'])
summary = pd.merge(most_rated_places, cuisine, on='placeID')
summary
# Out:
#    placeID         Rcuisine
# 0   135085        Fast_Food
# 1   132825          Mexican
# 2   135032        Cafeteria
# 3   135032     Contemporary
# 4   135052              Bar
# 5   135052  Bar_Pub_Brewery
# 6   132834          Mexican

# %%
cuisine['Rcuisine'].describe()
# Out:
# count         916
# unique         59
# top       Mexican
# freq          239
# Name: Rcuisine, dtype: object
